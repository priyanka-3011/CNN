# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiKalra21/Deep-Learning/blob/main/CNN/kkpg2134_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROJECT INFORMATION**
#
# ## **"Handwritten and Typed Digit Classification Using CNN and MNIST Dataset"**
#
# - Khushi Kalra - 055021
# - Priyanka Goyal - 055034

# %% [markdown]
# ## **1. Introduction**
#
# This project focuses on implementing a Convolutional Neural Network (CNN) to classify both handwritten and typed digits in different fonts using the MNIST dataset as the base model. The trained model is tested on images containing:
#
# - Handwritten digits (self sample).
# - Typed digits in different fonts (extracted from MS Word).
#
# By analyzing the model’s performance across these datasets, we can evaluate its robustness and potential applications.

# %% [markdown]
# ## **2. Project Overview**
# Digit recognition is a crucial aspect of automation in domains such as finance, postal services, education, and digital processing. Traditional character recognition models struggle with font variations and different handwriting styles.
#
# This project aims to:
#
# - Train a CNN model on the MNIST dataset.
# - Evaluate its performance on both typed digits (multiple fonts) and handwritten numbers.
# - Optimize the model for real-world applications requiring digit classification.

# %% [markdown]
# ## **3. Project Implementation**
#
# ### **3.1 Dataset Used**
#
# **Training Data:**
# - MNIST dataset (70,000 grayscale images of digits 0-9).
#
# **Testing Data:**
# - Typed numbers in different fonts (extracted from MS Word).
# - Handwritten numbers (collected from various individuals).
#
#
#
# ### **Data Collection**
#
# > The handwritten digit dataset was gathered from various individuals outside college premises, ensuring diversity in writing styles and conditions.
# > Additionally, the typed digit dataset was generated using multiple fonts in MS Word, introducing variations in printed numbers.
# >
# > This approach enhanced the model’s adaptability to different handwriting styles and font variations, making it robust for real-world scenarios.
#
#
# ### **3.2 Steps Followed**
#
# 1. Load and preprocess the MNIST dataset.
# 2. Build and train a CNN model using TensorFlow/Keras.
# 3. Save the trained model.
# 4. Download and preprocess external datasets (typed numbers in multiple fonts and handwritten numbers).
# 5. Evaluate model accuracy on different datasets.
# 6. Visualize predictions and analyze results.
#
#
#
# ### **3.3 CNN Model Architecture**
#
# #### **Input Layer:**
# - 28x28 grayscale images
#
# #### **Convolutional Layers:**
# - **Conv2D** (32 filters, 3x3, ReLU)
# - **MaxPooling** (2x2)
# - **Conv2D** (64 filters, 3x3, ReLU)
# - **MaxPooling** (2x2)
# - **Conv2D** (128 filters, 3x3, ReLU)
#
# #### **Fully Connected Layers:**
# - **Flatten Layer**
# - **Dense** (128 neurons, ReLU)
# - **Dense** (10 neurons, Softmax)
#
#
# ### **3.4 Model Training & Optimization**
#
# - **Optimizer Used:** Adam
# - **Loss Function:** Sparse Categorical Crossentropy
# - **Training Epochs:** 5
# - **Batch Size:** 32

# %% [markdown]
# ## **4. Results & Observations**
#
# | **Dataset**                        | **Accuracy (%)** |
# |-------------------------------------|-----------------|
# | MNIST Test Set                      | 98.97           |
# | Typed Numbers (Multiple Fonts)       | 61.11           |
# | Handwritten Digits (Collected Data)  | 68.89           |
#
# ### **Key Observations**
#
# - The model achieved high accuracy on the MNIST test set, as expected.
# - Accuracy slightly dropped for **typed numbers in multiple fonts**, indicating that font variations affected predictions.
# - Performance further decreased for **handwritten digits**, suggesting that the model was biased toward MNIST-style digits.
# - These results highlight the importance of **diverse training data** to improve generalization.

# %% [markdown]
# ## **5. Managerial Insights & Business Applications**
#
# ### **1. Banking & Financial Services**
# - **Automated Cheque & Document Processing:** AI-driven models can extract and verify handwritten/typed numerical data from cheques, invoices, and financial documents, reducing manual errors.
# - **Fraud Detection & Compliance:** Identifying anomalies in numerical handwriting can help detect fraudulent transactions and forged documents.
#
# ### **2. Education & E-Learning**
# - **AI-Powered Assessment Systems:** Automated evaluation of handwritten and typed exam responses for grading and plagiarism detection.
# - **Digital Transformation of Academic Records:** Conversion of handwritten historical academic records into searchable digital formats.
#
# ### **3. Logistics & Postal Services**
# - **Smart Address Recognition:** Enhancing efficiency in automated mail sorting by recognizing zip codes, tracking numbers, and addresses in handwritten forms.
# - **Delivery Optimization:** AI-powered systems can extract and process handwritten instructions on parcels to streamline last-mile delivery.
#
# ### **4. Retail & Automated Billing**
# - **OCR-Integrated POS Systems:** Digit recognition in invoices and receipts for seamless automated billing.
# - **Customer Self-Checkout:** Handwritten price tag recognition for quicker transactions in self-checkout kiosks.
#
# ### **5. Healthcare & Patient Data Management**
# - **Digitizing Medical Records:** Extracting handwritten prescriptions and patient information for seamless electronic health record (EHR) management.
# - **AI-Driven Diagnostic Support:** Recognizing numeric values in handwritten lab reports for faster and error-free processing.
#
# ### **6. Security & Access Control**
# - **AI-Based Handwriting Authentication:** Implementing numerical signature verification for secure access control in high-security environments.
# - **Forensic Handwriting Analysis:** Assisting law enforcement agencies in verifying handwritten numerical data on contracts and legal documents.

# %% [markdown]
# ## **6. Challenges & Recommendations**
#
# ### **Challenges Faced**
# - **Font Variability & Recognition Limitations:**
#   - The model struggled with certain font styles that significantly deviated from MNIST digits, leading to misclassification.
# - **Handwritten Digit Recognition Difficulties:**
#   - Due to the limited variety of handwriting samples, the model was biased toward MNIST-style digits, reducing its effectiveness on handwritten numbers.
# - **Image Preprocessing Issues:**
#   - Background noise, contrast variations, and distortions in collected images impacted preprocessing, affecting model performance.
#
# ### **Recommendations for Improvement**
# 1. **Implement Data Augmentation:**
#    - Introduce rotation, skewing, contrast enhancement, and noise reduction to improve the model’s ability to recognize variations in digits.
# 2. **Expand Training Data:**
#    - Incorporate a larger, more diverse dataset with various handwriting styles and font types to enhance generalization.
# 3. **Optimize Preprocessing Techniques:**
#    - Apply adaptive thresholding, contrast normalization, and denoising filters to improve image quality before classification.
# 4. **Leverage Transfer Learning:**
#    - Fine-tune the CNN model using pre-trained networks (e.g., VGG, ResNet) to adapt to different handwriting patterns and font styles.
# 5. **Improve Model Architecture:**
#    - Experiment with deeper architectures, attention mechanisms, or hybrid CNN-RNN models for better contextual understanding of digits.

# %% [markdown]
# ## **7. Conclusion**
# This project successfully developed a **CNN-based handwritten and typed digit classification model** using the MNIST dataset and additional custom datasets. While the model demonstrated high accuracy on MNIST, its performance declined when tested on typed numbers in various fonts and handwritten digits, highlighting key areas for improvement.
#
# ### **Key Takeaways:**
# - **Strong Performance on Standardized Data:** Achieved high accuracy on MNIST, proving CNNs’ effectiveness in digit recognition.
# - **Challenges with Real-World Variability:** Font differences, handwritten styles, and preprocessing issues affected predictions.
# - **Opportunities for Enhancement:** The model can be significantly improved by implementing data augmentation, transfer learning, and advanced preprocessing techniques.
#
# ### **Future Work:**
# 🔹 **Integrating a more diverse dataset** to enhance the model’s ability to generalize across different handwriting styles and font types.
# 🔹 **Exploring advanced deep learning techniques** such as GAN-based data synthesis to create more realistic training samples.
# 🔹 **Deploying the model in real-world applications** like automated form processing, banking document verification, and OCR-driven analytics.

# %% [markdown]
# ## **Analysis**

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Preprocess data: Reshape images to 28x28x1 and normalize pixel values (0-1)
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# Define CNN Model
model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),  # First Conv Layer
    layers.MaxPooling2D((2,2)),  # First MaxPooling Layer
    layers.Conv2D(64, (3,3), activation='relu'),  # Second Conv Layer
    layers.MaxPooling2D((2,2)),  # Second MaxPooling Layer
    layers.Conv2D(128, (3,3), activation='relu'),  # Third Conv Layer
    layers.Flatten(),  # Flatten output for Dense layers
    layers.Dense(128, activation='relu'),  # Fully connected layer
    layers.Dense(10, activation='softmax')  # Output layer for 10 classes (digits 0-9)
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
print("\n Training the CNN model on MNIST dataset...\n")
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\n Model Evaluation Complete!\nTest Accuracy: {test_acc:.4%}")

# Predict on a sample test image
sample_img = x_test[0].reshape(1, 28, 28, 1)  # Take first test image
predicted_label = np.argmax(model.predict(sample_img))

# Display the sample image with prediction
plt.figure(figsize=(4, 4))
plt.imshow(x_test[0].reshape(28,28), cmap='gray')
plt.title(f"Predicted Label: {predicted_label}", fontsize=14)
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  Training the CNN model on MNIST dataset...
#
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 65s 34ms/step - accuracy: 0.9070 - loss: 0.2975 - val_accuracy: 0.9851 - val_loss: 0.0475
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 84s 35ms/step - accuracy: 0.9870 - loss: 0.0426 - val_accuracy: 0.9895 - val_loss: 0.0303
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 67s 36ms/step - accuracy: 0.9910 - loss: 0.0290 - val_accuracy: 0.9895 - val_loss: 0.0330
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 77s 33ms/step - accuracy: 0.9932 - loss: 0.0211 - val_accuracy: 0.9923 - val_loss: 0.0246
# Epoch 5/5
# ...

# %% [markdown]
# ### Saving the model

# %%
# Save the trained CNN model in .keras format
model_save_path = "mnist_cnn_model.keras"
model.save(model_save_path)
print(f"Model saved successfully at '{model_save_path}'")

# Download the saved model file (for Google Colab users)
from google.colab import files
files.download(model_save_path)
print(f"Download initiated: '{model_save_path}'")
# Out:
# Model saved successfully at 'mnist_cnn_model.keras'
# Download initiated: 'mnist_cnn_model.keras'

# %%
import gdown
import os

# Define File ID and Output Path
file_id = "1GKtaW05XxWjfWJNpHxDEvdlipPfmZFdX"  # Update with correct File ID
output_path = "/content/test_image.png"

# Download the image from Google Drive
gdown.download(f"https://drive.google.com/uc?id={file_id}", output_path, quiet=False)

# Verify if the file was downloaded successfully
if os.path.exists(output_path):
    print(f"Image downloaded successfully at '{output_path}'")
else:
    print("Failed to download image. Check the File ID or network connection.")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GKtaW05XxWjfWJNpHxDEvdlipPfmZFdX
# To: /content/test_image.png
# 100%|██████████| 143k/143k [00:00<00:00, 69.2MB/s]
# Image downloaded successfully at '/content/test_image.png'

# %%
import gdown
import zipfile
import os

# Define File ID and Output Path
file_id = "1GKtaW05XxWjfWJNpHxDEvdlipPfmZFdX"
zip_path = "/content/images.zip"
extract_path = "/content/extracted_images"

# Download the ZIP file
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Verify if the ZIP file was downloaded successfully
if os.path.exists(zip_path):
    print(f"ZIP file downloaded successfully: {zip_path}")

    # Extract the ZIP file
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print(f"Files extracted to: {extract_path}")

else:
    print("Failed to download ZIP file. Check the File ID or network connection.")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GKtaW05XxWjfWJNpHxDEvdlipPfmZFdX
# To: /content/images.zip
# 100%|██████████| 143k/143k [00:00<00:00, 70.4MB/s]
# ZIP file downloaded successfully: /content/images.zip
# Files extracted to: /content/extracted_images

# %%
# Define extraction folder
extract_folder = "/content/extracted_images"

# Create the folder if it doesn't exist
os.makedirs(extract_folder, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_folder)

print(f" Files extracted to: {extract_folder}")

# List all extracted image files
image_files = sorted([f for f in os.listdir(extract_folder) if f.endswith(('.png', '.jpg', '.jpeg'))])
print(f" {len(image_files)} images found:", image_files)
# Out:
#  Files extracted to: /content/extracted_images
# ...

# %%
import matplotlib.pyplot as plt
import cv2

# Function to display images
def display_images(image_list, folder, num_images=5):
    plt.figure(figsize=(10, 5))

    for i, img_name in enumerate(image_list[:num_images]):
        img_path = os.path.join(folder, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for correct color display

        plt.subplot(1, num_images, i+1)
        plt.imshow(img, cmap='gray')
        plt.title(img_name)
        plt.axis("off")

    plt.show()

# Display images
display_images(image_files, extract_folder)

# %%
import numpy as np
import pandas as pd
import cv2

# Function to preprocess the image for CNN model
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale
    img = cv2.bitwise_not(img)  # Invert colors (black background, white digit)
    img_resized = cv2.resize(img, (28, 28))  # Resize to 28x28 pixels
    img_normalized = img_resized.astype('float32') / 255.0  # Normalize (0-1)

    # Reshape to match CNN input format (batch size, height, width, channels)
    img_final = np.expand_dims(img_normalized, axis=0)  # Add batch dimension
    img_final = np.expand_dims(img_final, axis=-1)  # Add channel dimension

    return img_final, img_resized  # Return processed image & resized for display

# List to store results
predictions_list = []

# Loop through all extracted images
for img_name in image_files:
    img_path = os.path.join(extract_folder, img_name)

    # Extract actual digit from the filename (last character before extension)
    actual_digit = int(img_name[-5])  # Example: "image_3.png" → digit = 3

    # Preprocess image
    img_input, img_display = preprocess_image(img_path)

    # Make prediction using CNN model
    predicted_digit = np.argmax(model.predict(img_input))

    # Store results
    predictions_list.append([img_name, actual_digit, predicted_digit])

# Convert to DataFrame
df_results = pd.DataFrame(predictions_list, columns=["Image Name", "Actual Digit", "Predicted Digit"])

# Display table
df_results
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# ...

# %%
import matplotlib.pyplot as plt

# Function to display image predictions
def display_predictions(df, num_images=5):
    plt.figure(figsize=(10, 5))

    for i in range(min(num_images, len(df))):
        img_name = df.loc[i, "Image Name"]
        actual = df.loc[i, "Actual Digit"]
        predicted = df.loc[i, "Predicted Digit"]

        img_path = os.path.join(extract_folder, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale

        plt.subplot(1, num_images, i+1)
        plt.imshow(img, cmap='gray')
        plt.title(f"Actual: {actual} | Predicted: {predicted}", fontsize=10)
        plt.axis("off")

    plt.show()

# Display the first 5 images with predictions
display_predictions(df_results, num_images=5)

# %%
# Directory where extracted images are stored
extract_folder = "/content/extracted_images"  # Update if needed
image_files = sorted(os.listdir(extract_folder))  # List all images

# List to store results
predictions_list = []

# Loop through all extracted images
for img_name in image_files:
    img_path = os.path.join(extract_folder, img_name)

    # Extract actual digit from filename (last character before extension)
    actual_digit = int(img_name[-5])  # Example: "image_3.png" → digit = 3

    # Preprocess image
    img_input, img_display = preprocess_image(img_path)

    # Make prediction using CNN model
    predicted_digit = np.argmax(model.predict(img_input))

    # Store results
    predictions_list.append([img_name, actual_digit, predicted_digit])

# Convert results to DataFrame
df_results = pd.DataFrame(predictions_list, columns=["Image Name", "Actual Digit", "Predicted Digit"])

# Add a column to check if prediction is correct
df_results["Correct"] = df_results["Actual Digit"] == df_results["Predicted Digit"]

# Calculate accuracy
accuracy = (df_results["Correct"].sum() / len(df_results)) * 100

# Display accuracy
print(f" Model Accuracy on Extracted Images: {accuracy:.2f}%")

# Show result table
df_results
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ...

# %%
# Display only incorrect predictions
df_incorrect = df_results[df_results["Correct"] == False]

if len(df_incorrect) > 0:
    print(" Incorrect Predictions:")
    display(df_incorrect)
else:
    print(" All images predicted correctly!")
# Out:
#  Incorrect Predictions:
#       Image Name  Actual Digit  Predicted Digit  Correct
# 5   Slice 14.jpg             4                1    False
# 9   Slice 18.jpg             8                5    False
# 15  Slice 23.jpg             3                5    False
# 16  Slice 24.jpg             4                2    False
# 18  Slice 26.jpg             6                0    False
# 21  Slice 29.jpg             9                2    False
# 29  Slice 36.jpg             6                5    False
# 30  Slice 37.jpg             7                2    False
# 32  Slice 39.jpg             9                0    False
# 36  Slice 42.jpg             2                3    False
# 38  Slice 44.jpg             4                2    False
# 41  Slice 47.jpg             7                2    False
# 42  Slice 48.jpg             8                5    False
# 43  Slice 49.jpg             9                2    False
# 44   Slice 5.jpg             5                7    False
# ...

# %%
# Function to display image predictions
def display_predictions(df, num_images=5):
    plt.figure(figsize=(10, 5))

    for i in range(min(num_images, len(df))):
        img_name = df.loc[i, "Image Name"]
        actual = df.loc[i, "Actual Digit"]
        predicted = df.loc[i, "Predicted Digit"]

        img_path = os.path.join(extract_folder, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale

        plt.subplot(1, num_images, i+1)
        plt.imshow(img, cmap='gray')
        plt.title(f"Actual: {actual} | Predicted: {predicted}", fontsize=10)
        plt.axis("off")

    plt.show()

# Display the first 5 images with predictions
display_predictions(df_results, num_images=5)

# %%
# Define file ID & download destination
file_id = "1fUM3bZ0fTjb-oBQ_QrYh9mXfc6E4po8k"
zip_path = "/content/images.zip"

# Download ZIP file from Google Drive
gdown.download(f"https://drive.google.com/uc?id={file_id}", zip_path, quiet=False)

# Extract images
extract_folder = "/content/extracted_images"
os.makedirs(extract_folder, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

print(f" Images extracted successfully to: {extract_folder}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fUM3bZ0fTjb-oBQ_QrYh9mXfc6E4po8k
# To: /content/images.zip
# 100%|██████████| 994k/994k [00:00<00:00, 45.7MB/s]
#  Images extracted successfully to: /content/extracted_images

# %%
import cv2
import numpy as np

def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale

    # Invert colors if background is black
    img = cv2.bitwise_not(img)

    img_resized = cv2.resize(img, (28, 28))  # Resize to 28x28 pixels
    img_normalized = img_resized.astype('float32') / 255.0  # Normalize (0-1)

    # Reshape to match CNN input format (batch size, height, width, channels)
    img_final = np.expand_dims(img_normalized, axis=0)  # Add batch dimension
    img_final = np.expand_dims(img_final, axis=-1)  # Add channel dimension

    return img_final, img_resized  # Return processed image & resized for display

# %%
import pandas as pd

# List extracted images
image_files = sorted(os.listdir(extract_folder))

# Store results
predictions_list = []

for img_name in image_files:
    img_path = os.path.join(extract_folder, img_name)

    # Extract actual digit from filename (last character before extension)
    actual_digit = int(img_name[-5])  # Example: "image_3.png" → digit = 3

    # Preprocess image
    img_input, img_display = preprocess_image(img_path)

    # Make prediction using CNN model
    predicted_digit = np.argmax(model.predict(img_input))

    # Store results
    predictions_list.append([img_name, actual_digit, predicted_digit])

# Convert results to DataFrame
df_results = pd.DataFrame(predictions_list, columns=["Image Name", "Actual Digit", "Predicted Digit"])

# Add a column to check if prediction is correct
df_results["Correct"] = df_results["Actual Digit"] == df_results["Predicted Digit"]

# Calculate accuracy
accuracy = (df_results["Correct"].sum() / len(df_results)) * 100

# Display accuracy
print(f" Model Accuracy on Extracted Images: {accuracy:.2f}%")

# Show result table
df_results
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# ...

# %%
# Display only incorrect predictions
df_incorrect = df_results[df_results["Correct"] == False]

if len(df_incorrect) > 0:
    print(" Incorrect Predictions:")
    display(df_incorrect)
else:
    print(" All images predicted correctly!")
# Out:
#  Incorrect Predictions:
#       Image Name  Actual Digit  Predicted Digit  Correct
# 0    Slice 1.jpg             1                2    False
# 12  Slice 20.jpg             0                6    False
# 13  Slice 21.jpg             1                2    False
# 24  Slice 31.jpg             1                5    False
# 32  Slice 39.jpg             9                1    False
# 35  Slice 41.jpg             1                3    False
# 36  Slice 42.jpg             2                1    False
# 43  Slice 49.jpg             9                7    False
# 44   Slice 5.jpg             5                2    False
# 53  Slice 58.jpg             8                2    False
# 57  Slice 61.jpg             1                0    False
# 60  Slice 64.jpg             4                1    False
# 61  Slice 65.jpg             5                2    False
# 62  Slice 66.jpg             6                2    False
# 68  Slice 71.jpg             1                9    False
# ...

# %%
import matplotlib.pyplot as plt

# Function to display image predictions
def display_predictions(df, num_images=5):
    plt.figure(figsize=(10, 5))

    for i in range(min(num_images, len(df))):
        img_name = df.loc[i, "Image Name"]
        actual = df.loc[i, "Actual Digit"]
        predicted = df.loc[i, "Predicted Digit"]

        img_path = os.path.join(extract_folder, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale

        plt.subplot(1, num_images, i+1)
        plt.imshow(img, cmap='gray')
        plt.title(f"Actual: {actual} | Predicted: {predicted}", fontsize=10)
        plt.axis("off")

    plt.show()

# Display the first 5 images with predictions
display_predictions(df_results, num_images=5)
